# %% [markdown]
# # Introduction
#
# This notebook guide through the simple pipeline to solve the [Toxic comment classification problem](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge) hosted on kaggle in year 2018.
#
# In this competition we are given the dataset of 160k  comments wikipedia comments which are manually labeled as `toxic`, `severe_toxic`,  `obscene`, `threat`, `insult`, `identity_hate`.
#
# This is multi label classification problem where we have to classify comments among all the labels.

# %% [markdown]
# # Methodology used
#
# I will use two bi-directional GRU (type of recurrent neural network) as base of my model in order to solve this problem. I will be using [keras API](https://www.tensorflow.org/api_docs/python/tf/keras) supported by Tensorflow for training the model because of its easy implementation.
#
#
# In order to understand basic pipeline of a NLP project you can read [this](https://) blog post.

# %% [markdown]
# ## Download data

# %% [markdown]
# We will download the data using kaggle API keys.
# In order to get yours go to your account page which is kaggle.com/`your_user_id`/account, and click "Create new API token" button. save the file on gdrive under 'kaggle/kaggle.json'. After doing that execute the following code.

# %%
# !pip3 -q install kaggle
# !pip3 -q install fasttext
# !pip3 -q install sentencepiece
# Out:
#      |████████████████████████████████| 61kB 2.0MB/s
#   Building wheel for fasttext (setup.py) ... done
#      |████████████████████████████████| 1.0MB 2.8MB/s

# %%
# !pip3 -q install wandb
# Out:
#      |████████████████████████████████| 1.3MB 2.8MB/s
#      |████████████████████████████████| 92kB 12.0MB/s
#      |████████████████████████████████| 460kB 57.5MB/s
#      |████████████████████████████████| 92kB 11.7MB/s
#      |████████████████████████████████| 102kB 12.1MB/s
#      |████████████████████████████████| 71kB 9.9MB/s
#      |████████████████████████████████| 256kB 54.6MB/s
#      |████████████████████████████████| 184kB 53.4MB/s
#   Building wheel for gql (setup.py) ... done
#   Building wheel for shortuuid (setup.py) ... done
#   Building wheel for watchdog (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
# !wandb login 5d07d062006892c07c0bf6c7ac5608f33b8cb016
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Successfully logged in to Weights & Biases!

# %%
import wandb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle/

# %%
# !cp 'drive/My Drive/kaggle/kaggle.json' ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c jigsaw-toxic-comment-classification-challenge
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/1.39M [00:00<?, ?B/s]
# 100% 1.39M/1.39M [00:00<00:00, 98.2MB/s]
# Downloading test.csv.zip to /content
#  38% 9.00M/23.4M [00:00<00:00, 42.0MB/s]
# 100% 23.4M/23.4M [00:00<00:00, 78.2MB/s]
# Downloading train.csv.zip to /content
#  34% 9.00M/26.3M [00:00<00:00, 33.4MB/s]
# 100% 26.3M/26.3M [00:00<00:00, 75.7MB/s]
# Downloading test_labels.csv.zip to /content
#   0% 0.00/1.46M [00:00<?, ?B/s]
# 100% 1.46M/1.46M [00:00<00:00, 98.0MB/s]

# %%
# !unzip -q test.csv.zip
# !unzip -q train.csv.zip
# !unzip -q test_labels.csv.zip
# !unzip -q sample_submission.csv.zip

# %%
# !rm *zip

# %%
# !ls
# Out:
# drive	     sample_submission.csv  test_labels.csv  wandb
# sample_data  test.csv		    train.csv

# %% [markdown]
# # Imports and initialization

# %%
import os
import numpy as np
import pandas as pd
import tqdm
import nltk
from nltk.corpus import stopwords
import re
import string
from gensim.models import KeyedVectors

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from wandb.keras import WandbCallback

# %%
from sklearn import metrics
from tensorflow.keras import backend as K
import tensorflow as tf

# %%
import fasttext
import sentencepiece as spm

# %%
TEST_FILE = './test.csv'
TRAIN_FILE = './train.csv'
SAMPLE_SUB = './sample_submission.csv'
TEST_LABEL = './test_labels.csv'

# %%
maxlen = 300
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]

# %%
UNKNOWN_WORD = "<unk>"

# %%
MODEL_DIR = "models/"
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# %%time

train = pd.read_csv(TRAIN_FILE)
test = pd.read_csv(TEST_FILE)
sample = pd.read_csv(SAMPLE_SUB)
# Out:
# CPU times: user 1.29 s, sys: 169 ms, total: 1.46 s
# Wall time: 1.47 s

# %%
train.head()
# Out:
#                  id  ... identity_hate
# 0  0000997932d777bf  ...             0
# 1  000103f0d9cfb60f  ...             0
# 2  000113f07ec002fd  ...             0
# 3  0001b41b1c6bb37e  ...             0
# 4  0001d958c54c6e35  ...             0
#
# [5 rows x 8 columns]

# %%
test.head()
# Out:
#                  id                                       comment_text
# 0  00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1  0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2  00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3  00017563c3f7919a  :If you have a look back at the source, the in...
# 4  00017695ad8997eb          I don't anonymously edit articles at all.

# %% [markdown]
# # Preprocessing text

# %% [markdown]
# For our current problem we are just removing the newline characters `\n` and numbers from the text. We will separate the word and special characters. Doing so will help us down the line (to be exact it will be helpful in tokenization).

# %%
re_tok = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')

def clean_text(s):
    return re_tok.sub(r' \1 ', s).lower()

def clean_numbers(x):
    x = re.sub('[0-9]{5,}', '#####', x)
    x = re.sub('[0-9]{4}', '####', x)
    x = re.sub('[0-9]{3}', '###', x)
    x = re.sub('[0-9]{2}', '##', x)
    return x

def remove_nl(x):
  x = re.sub('\n', ' ', x)
  return x


def add_nl(x):
  re_nl = re.compile(f'([?.!;:])')
  x = re_nl.sub(r'\1 \n', x).lower()
  return x

# %%
# %%time

print("Adding new line for sentencepiece in train comments")
train["comment_spm"] = train["comment_text"].apply(add_nl)
print("Adding new line for sentencepiece in test comments")
test["comment_spm"] = test["comment_text"].apply(add_nl)
print("Removing numbers from train comments")
# Out:
# Adding new line for sentencepiece in train comments
# Adding new line for sentencepiece in test comments
# Removing numbers from train comments
# CPU times: user 5.31 s, sys: 36.3 ms, total: 5.35 s
# Wall time: 5.35 s

# %%
train.head()
# Out:
#                  id  ...                                        comment_spm
# 0  0000997932d777bf  ...  explanation\nwhy the edits made under my usern...
# 1  000103f0d9cfb60f  ...  d'aww! \n he matches this background colour i'...
# 2  000113f07ec002fd  ...  hey man, i'm really not trying to edit war. \n...
# 3  0001b41b1c6bb37e  ...  "\nmore\ni can't make any real suggestions on ...
# 4  0001d958c54c6e35  ...  you, sir, are my hero. \n any chance you remem...
#
# [5 rows x 9 columns]

# %%
test.head()
# Out:
#                  id  ...                                        comment_spm
# 0  00001cee341fdb12  ...  yo bitch ja rule is more succesful then you'll...
# 1  0000247867823ef7  ...  == from rfc == \n\n the title is fine as it is...
# 2  00013b17ad220c46  ...  " \n\n == sources == \n\n * zawe ashton on lap...
# 3  00017563c3f7919a  ...  : \nif you have a look back at the source, the...
# 4  00017695ad8997eb  ...       i don't anonymously edit articles at all. \n
#
# [5 rows x 3 columns]

# %% [markdown]
# # Training BPE model from scratch using sentencepiece

# %% [markdown]
# Sentencepiece is a package developed by google in order to create optimal tokenization technique and make vocabulary of fixed size and reduce the number of unknown tokens.
#
# You can use [this](https://github.com/google/sentencepiece/blob/master/python/sentencepiece_python_module_example.ipynb) code example to check out the library.

# %%
SENT_PIECE = 'pre_sentpc.txt'

def createFile(name, data):
  with open(name, 'w') as f:
    for item in data:
        f.write("%s\n" % item)

all_comments = train['comment_spm'] +  test['comment_spm'] 

createFile(SENT_PIECE,all_comments)

# %%
# !ls
# Out:
# drive	pre_sentpc.txt	sample_submission.csv  test_labels.csv	wandb
# models	sample_data	test.csv	       train.csv

# %%
# %%time

spm.SentencePieceTrainer.Train("--input={} --model_prefix=sentence_pc --model_type=bpe --vocab_size=10000".format(SENT_PIECE))
# Out:
# CPU times: user 1min 5s, sys: 713 ms, total: 1min 5s
# Wall time: 58.1 s
# True

# %%
sp_tokenizer = spm.SentencePieceProcessor()
sp_tokenizer.load('sentence_pc.model')
# Out:
# True

# %%
# %%time

def tokenize_comment(comment):
  return " ".join(sp_tokenizer.EncodeAsPieces(comment)).lower()

print("tokenize train comments")
train["comment_token"] = train["comment_text"].apply(tokenize_comment)
print("tokenize test comments")
test["comment_token"] = test["comment_text"].apply(tokenize_comment)
# Out:
# tokenize train comments
# tokenize test comments
# CPU times: user 1min 16s, sys: 247 ms, total: 1min 16s
# Wall time: 1min 16s

# %%
train.head()
# Out:
#                  id  ...                                      comment_token
# 0  0000997932d777bf  ...  ▁ e x pl an ation ▁ w hy ▁the ▁edits ▁made ▁un...
# 1  000103f0d9cfb60f  ...  ▁ d ' a ww ! ▁ h e ▁matches ▁this ▁background ...
# 2  000113f07ec002fd  ...  ▁ h ey ▁man , ▁ i ' m ▁really ▁not ▁trying ▁to...
# 3  0001b41b1c6bb37e  ...  ▁" ▁ m ore ▁ i ▁can ' t ▁make ▁any ▁real ▁sugg...
# 4  0001d958c54c6e35  ...  ▁ y ou , ▁sir , ▁are ▁my ▁hero . ▁ a ny ▁chanc...
#
# [5 rows x 10 columns]

# %%
test.head()
# Out:
#                  id  ...                                      comment_token
# 0  00001cee341fdb12  ...  ▁ y o ▁bitch ▁ j a ▁ r u le ▁is ▁more ▁suc ces...
# 1  0000247867823ef7  ...  ▁== ▁ f rom ▁ r f c ▁== ▁ t he ▁title ▁is ▁fin...
# 2  00013b17ad220c46  ...  ▁" ▁== ▁ s our ces ▁== ▁* ▁ z a we ▁ a s ht on...
# 3  00017563c3f7919a  ...  ▁: i f ▁you ▁have ▁a ▁look ▁back ▁at ▁the ▁sou...
# 4  00017695ad8997eb  ...  ▁ i ▁don ' t ▁anonymous ly ▁edit ▁articles ▁at...
#
# [5 rows x 4 columns]

# %%
createFile('pre_fasttext.txt',train['comment_token'] +  test['comment_token'] )

# %% [markdown]
# # Training a FastText embedding model from scrach
#
# Creating custom embedding for our models using FastText library.

# %%
import fasttext

# %% [markdown]
# ### Installing Fasttext from source

# %%
! wget https://github.com/facebookresearch/fastText/archive/v0.9.1.zip
! unzip -q v0.9.1.zip
# Out:
# --2019-11-02 03:38:37--  https://github.com/facebookresearch/fastText/archive/v0.9.1.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/facebookresearch/fastText/zip/v0.9.1 [following]
# --2019-11-02 03:38:37--  https://codeload.github.com/facebookresearch/fastText/zip/v0.9.1
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘v0.9.1.zip’
#
# v0.9.1.zip              [  <=>               ]   4.13M  18.3MB/s    in 0.2s
#
# 2019-11-02 03:38:37 (18.3 MB/s) - ‘v0.9.1.zip’ saved [4327207]

# %%
! cd fastText-0.9.1 &&  make
# Out:
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/args.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/matrix.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/dictionary.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/loss.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/productquantizer.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/densematrix.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/quantmatrix.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/vector.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/model.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/utils.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/meter.cc
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG -c src/fasttext.cc
# src/fasttext.cc: In member function ‘void fasttext::FastText::quantize(const fasttext::Args&)’:
# src/fasttext.cc:323:45: warning: ‘std::vector<int> fasttext::FastText::selectEmbeddings(int32_t) const’ is deprecated: selectEmbeddings is being deprecated. [-Wdeprecated-declarations]
#      auto idx = selectEmbeddings(qargs.cutoff);
#                                              ^
# src/fasttext.cc:293:22: note: declared here
#  std::vector<int32_t> FastText::selectEmbeddings(int32_t cutoff) const {
#                       ^~~~~~~~
# src/fasttext.cc: In member function ‘void fasttext::FastText::lazyComputeWordVectors()’:
# src/fasttext.cc:551:40: warning: ‘void fasttext::FastText::precomputeWordVectors(fasttext::DenseMatrix&)’ is deprecated: precomputeWordVectors is being deprecated. [-Wdeprecated-declarations]
#      precomputeWordVectors(*wordVectors_);
#                                         ^
# src/fasttext.cc:534:6: note: declared here
#  void FastText::precomputeWordVectors(DenseMatrix& wordVectors) {
#       ^~~~~~~~
# c++ -pthread -std=c++0x -march=native -O3 -funroll-loops -DNDEBUG args.o matrix.o dictionary.o loss.o productquantizer.o densematrix.o quantmatrix.o vector.o model.o utils.o meter.o fasttext.o src/main.cc -o fasttext

# %% [markdown]
# ### Training the fasttext model

# %%
# %%time

! cd fastText-0.9.1 && ./fasttext skipgram -input ../pre_fasttext.txt -output ../embed_model -epoch 6 -lr 0.05 -dim 300
# 8206, 1.166972
# Out:
# Read 34M words
# Number of words:  17790
# Number of labels: 0
# tcmalloc: large alloc 2421350400 bytes == 0x56405217e000 @  0x7fe39f295887 0x5640490dcb7d 0x5640490e7028 0x5640490ee2e4 0x5640490f4092 0x5640490becc7 0x7fe39e332b97 0x5640490bef8a
# Progress: 100.0% words/sec/thread:   13352 lr:  0.000000 loss:  1.499305 ETA:   0h 0m
# CPU times: user 16.9 s, sys: 2.81 s, total: 19.7 s
# Wall time: 22min 12s

# %%
EMBEDDING_FILE = "embed_model.bin"

# %%
vocabs = [sp_tokenizer.id_to_piece(id) for id in range(sp_tokenizer.get_piece_size())]

# %%
# %%time
embed_model = fasttext.load_model(EMBEDDING_FILE)
# Out:
# CPU times: user 379 ms, sys: 1.58 s, total: 1.95 s
# Wall time: 1.95 s

# %% [markdown]
# ### Creating Embedding matrix

# %%
not_present = []

# %%
# %%time 

nb_words = len(vocabs)
not_found = []
embedding_matrix = np.zeros((nb_words, 300), dtype=np.float64)

for word in vocabs:
    try:
      index = sp_tokenizer.encode_as_ids(word)[0]
      embedding_matrix[index] = embed_model[word]
    except:
      not_found.append(word)
# Out:
# CPU times: user 267 ms, sys: 6.98 ms, total: 274 ms
# Wall time: 275 ms

# %%
len(not_found)
# Out:
# 1

# %% [markdown]
# Deleting the unrequired variables from memory as the memory available to us is always limited. More available memory means bigger batch size of our training model.

# %%
del all_comments

# %% [markdown]
# # Prepare inputs and output

# %%
def text_to_ids(comment):
  return sp_tokenizer.encode_as_ids(comment)

# %%
# %%time
train_X =  train["comment_spm"].apply(text_to_ids)
test_X = test["comment_spm"].apply(text_to_ids)
# Out:
# CPU times: user 1min 13s, sys: 578 ms, total: 1min 13s
# Wall time: 1min 13s

# %%
train_X = pad_sequences(train_X, maxlen=maxlen)
test_X = pad_sequences(test_X, maxlen=maxlen)

# %%
train_y = train[list_classes].values

# %% [markdown]
# # Define model and prepare for training

# %% [markdown]
# This compition evaluates a model based on the mean column-wise ROC AUC.

# %%
def auc(y_true, y_pred):
    auc = tf.metrics.mean(tf.metrics.auc(y_true, y_pred, curve='ROC'))
    K.get_session().run(tf.local_variables_initializer())
    return auc

# %%
X_train, X_eval, y_train, y_eval = train_test_split(train_X, train_y, test_size=0.1, random_state=101)

# %%
def get_model(embedding_matrix, sequence_length, dropout_rate, recurrent_units, dense_size, embed_train= False):
  input_layer = tf.keras.layers.Input(shape=(sequence_length,))
  embedding_layer = tf.keras.layers.Embedding(embedding_matrix.shape[0], embedding_matrix.shape[1], weights=[embedding_matrix], trainable=embed_train)(input_layer)
  x = tf.keras.layers.Dropout(dropout_rate)(embedding_layer)
  x = tf.keras.layers.Bidirectional(tf.keras.layers.CuDNNGRU(recurrent_units, return_sequences=True))(x)
  x = tf.keras.layers.Dropout(dropout_rate)(x)
  x = tf.keras.layers.Bidirectional(tf.keras.layers.CuDNNGRU(recurrent_units, return_sequences=True))(x)
  avg_pool = tf.keras.layers.GlobalAveragePooling1D()(x)
  max_pool = tf.keras.layers.GlobalMaxPooling1D()(x)
  x =  tf.compat.v1.keras.layers.concatenate([avg_pool, max_pool])
  x = tf.keras.layers.Dropout(dropout_rate)(x)
  x = tf.keras.layers.Dense(dense_size, activation="relu")(x)
  x = tf.keras.layers.Dropout(dropout_rate)(x)
  output_layer = tf.keras.layers.Dense(6, activation="sigmoid")(x)
  model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
  adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
  model.compile(optimizer=adam, loss=tf.keras.losses.binary_crossentropy, metrics=['accuracy', auc])
  return model

# %%
get_model_func = lambda: get_model(embedding_matrix, maxlen, 0.4, 120, 512, embed_train=False )
model = get_model_func()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 300, 300)     3000000     input_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300, 300)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 300, 240)     303840      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300, 240)     0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 300, 240)     260640      dropout_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 240)          0           bidirectional_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 240)          0           bidirectional_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 480)          0           global_average_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 480)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          246272      dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            3078        dropout_7[0][0]
# ==================================================================================================
# Total params: 3,813,830
# Trainable params: 813,830
# Non-trainable params: 3,000,000
# __________________________________________________________________________________________________

# %%
# checkpoint = tf.keras.callbacks.ModelCheckpoint('models/model-best.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='min')
checkpoint = tf.keras.callbacks.ModelCheckpoint('models/model-best.h5', verbose=1, monitor='val_acc',save_best_only=True, mode='max')

# %%
wandb.init(project="Toxic Comment Classification",name="Keras BPE 10k vocab 228bs")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/vksbhandary/Toxic+Comment+Classification" target="_blank">https://app.wandb.ai/vksbhandary/Toxic+Comment+Classification</a><br/>
#                 Run page: <a href="https://app.wandb.ai/vksbhandary/Toxic+Comment+Classification/runs/zktnacam" target="_blank">https://app.wandb.ai/vksbhandary/Toxic+Comment+Classification/runs/zktnacam</a><br/>
# W&B Run: https://app.wandb.ai/vksbhandary/Toxic+Comment+Classification/runs/zktnacam

# %%
# stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
stop = tf.keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', verbose=1, patience=30)

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_acc', patience=2,  verbose=1,  factor=0.2,  mode='max', min_lr=0.000001)

# %% [markdown]
# # Training the model

# %%
model.fit(X_train, y_train, batch_size=228, validation_split=0.1, callbacks=[checkpoint, stop, WandbCallback(), learning_rate_reduction ], epochs=200)
# Out:
# Train on 129251 samples, validate on 14362 samples
# Epoch 1/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0757 - acc: 0.9751 - auc: 0.7905
# Epoch 00001: val_acc improved from -inf to 0.98128, saving model to models/model-best.h5
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0757 - acc: 0.9751 - auc: 0.7907 - val_loss: 0.0522 - val_acc: 0.9813 - val_auc: 0.8889
# Epoch 2/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0549 - acc: 0.9804 - auc: 0.9109
# Epoch 00002: val_acc improved from 0.98128 to 0.98205, saving model to models/model-best.h5
# 129251/129251 [==============================] - 237s 2ms/sample - loss: 0.0549 - acc: 0.9804 - auc: 0.9109 - val_loss: 0.0496 - val_acc: 0.9820 - val_auc: 0.9251
# Epoch 3/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0520 - acc: 0.9812 - auc: 0.9332
# Epoch 00003: val_acc improved from 0.98205 to 0.98283, saving model to models/model-best.h5
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0520 - acc: 0.9812 - auc: 0.9332 - val_loss: 0.0461 - val_acc: 0.9828 - val_auc: 0.9394
# Epoch 4/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0498 - acc: 0.9818 - auc: 0.9438
# Epoch 00004: val_acc improved from 0.98283 to 0.98313, saving model to models/model-best.h5
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0499 - acc: 0.9818 - auc: 0.9438 - val_loss: 0.0452 - val_acc: 0.9831 - val_auc: 0.9475
# Epoch 5/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0480 - acc: 0.9821 - auc: 0.9503
# Epoch 00005: val_acc improved from 0.98313 to 0.98320, saving model to models/model-best.h5
# 129251/129251 [==============================] - 238s 2ms/sample - loss: 0.0480 - acc: 0.9821 - auc: 0.9503 - val_loss: 0.0439 - val_acc: 0.9832 - val_auc: 0.9527
# Epoch 6/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0464 - acc: 0.9826 - auc: 0.9547
# Epoch 00006: val_acc improved from 0.98320 to 0.98343, saving model to models/model-best.h5
# 129251/129251 [==============================] - 238s 2ms/sample - loss: 0.0464 - acc: 0.9826 - auc: 0.9547 - val_loss: 0.0441 - val_acc: 0.9834 - val_auc: 0.9565
# Epoch 7/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0454 - acc: 0.9830 - auc: 0.9580
# Epoch 00007: val_acc improved from 0.98343 to 0.98380, saving model to models/model-best.h5
# 129251/129251 [==============================] - 241s 2ms/sample - loss: 0.0454 - acc: 0.9830 - auc: 0.9580 - val_loss: 0.0423 - val_acc: 0.9838 - val_auc: 0.9594
# Epoch 8/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0443 - acc: 0.9833 - auc: 0.9605
# Epoch 00008: val_acc improved from 0.98380 to 0.98392, saving model to models/model-best.h5
# 129251/129251 [==============================] - 241s 2ms/sample - loss: 0.0443 - acc: 0.9833 - auc: 0.9605 - val_loss: 0.0427 - val_acc: 0.9839 - val_auc: 0.9616
# Epoch 9/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0429 - acc: 0.9835 - auc: 0.9626
# Epoch 00009: val_acc improved from 0.98392 to 0.98422, saving model to models/model-best.h5
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0429 - acc: 0.9835 - auc: 0.9626 - val_loss: 0.0422 - val_acc: 0.9842 - val_auc: 0.9635
# Epoch 10/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0422 - acc: 0.9838 - auc: 0.9643
# Epoch 00010: val_acc did not improve from 0.98422
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0422 - acc: 0.9838 - auc: 0.9643 - val_loss: 0.0421 - val_acc: 0.9841 - val_auc: 0.9651
# Epoch 11/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0411 - acc: 0.9841 - auc: 0.9658
# Epoch 00011: val_acc improved from 0.98422 to 0.98455, saving model to models/model-best.h5
# 129251/129251 [==============================] - 241s 2ms/sample - loss: 0.0411 - acc: 0.9841 - auc: 0.9658 - val_loss: 0.0420 - val_acc: 0.9846 - val_auc: 0.9664
# Epoch 12/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0402 - acc: 0.9844 - auc: 0.9670
# Epoch 00012: val_acc improved from 0.98455 to 0.98458, saving model to models/model-best.h5
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0403 - acc: 0.9844 - auc: 0.9670 - val_loss: 0.0414 - val_acc: 0.9846 - val_auc: 0.9676
# Epoch 13/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0397 - acc: 0.9847 - auc: 0.9681
# Epoch 00013: val_acc did not improve from 0.98458
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0397 - acc: 0.9846 - auc: 0.9681 - val_loss: 0.0411 - val_acc: 0.9845 - val_auc: 0.9687
# Epoch 14/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0370 - acc: 0.9854 - auc: 0.9691
# Epoch 00014: val_acc improved from 0.98458 to 0.98481, saving model to models/model-best.h5
# 129251/129251 [==============================] - 237s 2ms/sample - loss: 0.0370 - acc: 0.9854 - auc: 0.9691 - val_loss: 0.0408 - val_acc: 0.9848 - val_auc: 0.9696
# Epoch 15/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0363 - acc: 0.9858 - auc: 0.9700
# Epoch 00015: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 237s 2ms/sample - loss: 0.0363 - acc: 0.9858 - auc: 0.9700 - val_loss: 0.0409 - val_acc: 0.9848 - val_auc: 0.9704
# Epoch 16/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0362 - acc: 0.9857 - auc: 0.9708
# Epoch 00016: val_acc did not improve from 0.98481
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0362 - acc: 0.9857 - auc: 0.9708 - val_loss: 0.0409 - val_acc: 0.9847 - val_auc: 0.9712
# Epoch 17/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9858 - auc: 0.9716
# Epoch 00017: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0356 - acc: 0.9858 - auc: 0.9716 - val_loss: 0.0411 - val_acc: 0.9847 - val_auc: 0.9719
# Epoch 18/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0358 - acc: 0.9858 - auc: 0.9722
# Epoch 00018: val_acc did not improve from 0.98481
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0358 - acc: 0.9858 - auc: 0.9722 - val_loss: 0.0411 - val_acc: 0.9848 - val_auc: 0.9726
# Epoch 19/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9859 - auc: 0.9729
# Epoch 00019: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0355 - acc: 0.9859 - auc: 0.9729 - val_loss: 0.0411 - val_acc: 0.9847 - val_auc: 0.9732
# Epoch 20/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9859 - auc: 0.9735
# Epoch 00020: val_acc did not improve from 0.98481
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-06.
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0356 - acc: 0.9860 - auc: 0.9735 - val_loss: 0.0411 - val_acc: 0.9847 - val_auc: 0.9737
# Epoch 21/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0354 - acc: 0.9860 - auc: 0.9740
# Epoch 00021: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0354 - acc: 0.9860 - auc: 0.9740 - val_loss: 0.0411 - val_acc: 0.9847 - val_auc: 0.9742
# Epoch 22/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0357 - acc: 0.9859 - auc: 0.9745
# Epoch 00022: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0357 - acc: 0.9859 - auc: 0.9745 - val_loss: 0.0411 - val_acc: 0.9847 - val_auc: 0.9747
# Epoch 23/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9858 - auc: 0.9750
# Epoch 00023: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0355 - acc: 0.9858 - auc: 0.9750 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9752
# Epoch 24/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9859 - auc: 0.9754
# Epoch 00024: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0356 - acc: 0.9859 - auc: 0.9754 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9756
# Epoch 25/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9859 - auc: 0.9758
# Epoch 00025: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 238s 2ms/sample - loss: 0.0355 - acc: 0.9859 - auc: 0.9758 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9760
# Epoch 26/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9859 - auc: 0.9762
# Epoch 00026: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 238s 2ms/sample - loss: 0.0355 - acc: 0.9859 - auc: 0.9762 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9764
# Epoch 27/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9859 - auc: 0.9766
# Epoch 00027: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0355 - acc: 0.9859 - auc: 0.9766 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9767
# Epoch 28/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0353 - acc: 0.9860 - auc: 0.9769
# Epoch 00028: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0353 - acc: 0.9860 - auc: 0.9769 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9771
# Epoch 29/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0357 - acc: 0.9858 - auc: 0.9773
# Epoch 00029: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0357 - acc: 0.9858 - auc: 0.9773 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9774
# Epoch 30/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9858 - auc: 0.9776
# Epoch 00030: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 237s 2ms/sample - loss: 0.0356 - acc: 0.9858 - auc: 0.9776 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9777
# Epoch 31/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0358 - acc: 0.9858 - auc: 0.9778
# Epoch 00031: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 238s 2ms/sample - loss: 0.0357 - acc: 0.9858 - auc: 0.9778 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9780
# Epoch 32/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9858 - auc: 0.9781
# Epoch 00032: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 239s 2ms/sample - loss: 0.0356 - acc: 0.9858 - auc: 0.9781 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9782
# Epoch 33/200
# 129048/129251 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9859 - auc: 0.9784
# Epoch 00033: val_acc did not improve from 0.98481
# 129251/129251 [==============================] - 240s 2ms/sample - loss: 0.0355 - acc: 0.9859 - auc: 0.9784 - val_loss: 0.0412 - val_acc: 0.9847 - val_auc: 0.9785
# Epoch 34/200
#  92568/129251 [====================>.........] - ETA: 1:05 - loss: 0.0354 - acc: 0.9860 - auc: 0.9786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-a3af77ede717> in <module>()
# ----> 1 model.fit(X_train, y_train, batch_size=228, validation_split=0.1, callbacks=[checkpoint, stop, WandbCallback(), learning_rate_reduction ], epochs=200)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/wandb/keras/__init__.py in new_arrays(*args, **kwargs)
#      94             for cbk in cbks:
#      95                 set_wandb_attrs(cbk, (val_inputs[0], val_targets[0]))
# ---> 96         return old_arrays(*args, **kwargs)
#      97
#      98     def new_generator(*args, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluate Model

# %%
from sklearn.metrics import roc_auc_score

# %%
# !ls -al models
# Out:
# total 21344
# drwxr-xr-x 2 root root     4096 Nov  2 04:08 .
# drwxr-xr-x 1 root root     4096 Nov  2 04:01 ..
# -rw-r--r-- 1 root root 21847624 Nov  2 04:52 model-best.h5

# %%
eval_p = model.predict([X_eval], batch_size=1024, verbose=1)

print(roc_auc_score(y_eval, eval_p))
# Out:
# 15958/15958 [==============================] - 6s 393us/sample
# 0.9885745996484667

# %% [markdown]
# # Predict using model

# %%
preds = model.predict([test_X], batch_size=1024, verbose=1)
# Out:
# 153164/153164 [==============================] - 60s 391us/sample

# %%
sample['id'] = test['id']
sample[list_classes] = preds
sample.head()
# Out:
#                  id     toxic  ...        insult  identity_hate
# 0  00001cee341fdb12  0.999983  ...  9.752811e-01   6.700060e-01
# 1  0000247867823ef7  0.000217  ...  1.013279e-05   1.788139e-07
# 2  00013b17ad220c46  0.000803  ...  6.657839e-05   3.099442e-06
# 3  00017563c3f7919a  0.000004  ...  4.768372e-07   0.000000e+00
# 4  00017695ad8997eb  0.000825  ...  4.631281e-05   1.549721e-06
#
# [5 rows x 7 columns]

# %%
sample.to_csv("submission.csv", index=False)

# %%
# !kaggle competitions submit -c jigsaw-toxic-comment-classification-challenge -f submission.csv -m "Submission through colab: BPE test bs 228 10k vocab"
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# 100% 20.0M/20.0M [00:00<00:00, 29.3MB/s]
# Successfully submitted to Toxic Comment Classification Challenge
